# %%
import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical


# ============================================================
# Paths
# ============================================================

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\megambmarketname_n.xls"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "fa_"


# ============================================================
# Load Dataset
# ============================================================

df = pd.read_excel(DATASET_PATH)
df.columns = df.columns.str.strip()

required_columns = ["District Name", "Block Name", "Market Name"]

for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"Missing required column: {col}")

df = df.dropna()
df = df.drop_duplicates()

for col in required_columns:
    df[col] = df[col].astype(str).str.strip()


# ============================================================
# Feature Engineering
# ============================================================

df["district_market_count"] = df.groupby("District Name")["Market Name"].transform("count")
df["block_market_count"] = df.groupby("Block Name")["Market Name"].transform("count")

df["market_name_length"] = df["Market Name"].apply(len)
df["block_name_length"] = df["Block Name"].apply(len)
df["district_name_length"] = df["District Name"].apply(len)

df["route_density_score"] = (
    df["district_market_count"] * 0.5 +
    df["block_market_count"] * 0.4 +
    df["market_name_length"] * 0.1
)

df["trade_route_category"] = pd.qcut(
    df["route_density_score"],
    q=3,
    labels=[
        "Low Route Priority",
        "Medium Route Priority",
        "High Route Priority"
    ],
    duplicates="drop"
)


# ============================================================
# Encoding
# ============================================================

label_encoders = {}

for col in required_columns:
    le = LabelEncoder()
    df[col + "_encoded"] = le.fit_transform(df[col])
    label_encoders[col] = le

target_encoder = LabelEncoder()
df["target"] = target_encoder.fit_transform(df["trade_route_category"])


# ============================================================
# Features and Target
# ============================================================

feature_cols = [
    "District Name_encoded",
    "Block Name_encoded",
    "Market Name_encoded",
    "district_market_count",
    "block_market_count",
    "market_name_length",
    "block_name_length",
    "district_name_length",
    "route_density_score"
]

X = df[feature_cols].values
y = df["target"].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# ============================================================
# Firefly Algorithm Feature Selection
# ============================================================

def fitness_function(mask, X_data, y_data):
    selected_features = np.where(mask == 1)[0]

    if len(selected_features) == 0:
        return 0

    X_selected = X_data[:, selected_features]

    X_train_fs, X_test_fs, y_train_fs, y_test_fs = train_test_split(
        X_selected,
        y_data,
        test_size=0.2,
        random_state=42,
        stratify=y_data
    )

    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=8,
        random_state=42
    )

    model.fit(X_train_fs, y_train_fs)
    pred = model.predict(X_test_fs)

    accuracy = accuracy_score(y_test_fs, pred)
    feature_penalty = len(selected_features) / X_data.shape[1]

    return accuracy - (0.01 * feature_penalty)


def firefly_feature_selection(
    X_data,
    y_data,
    population_size=20,
    generations=25,
    alpha=0.2,
    beta0=1.0,
    gamma=1.0
):
    num_features = X_data.shape[1]

    fireflies = np.random.rand(population_size, num_features)
    fitness = np.zeros(population_size)

    best_position = None
    best_fitness = -np.inf
    fitness_history = []

    for generation in range(generations):

        for i in range(population_size):
            binary_firefly = (fireflies[i] > 0.5).astype(int)

            if np.sum(binary_firefly) == 0:
                binary_firefly[np.random.randint(0, num_features)] = 1

            fitness[i] = fitness_function(binary_firefly, X_data, y_data)

            if fitness[i] > best_fitness:
                best_fitness = fitness[i]
                best_position = fireflies[i].copy()

        for i in range(population_size):
            for j in range(population_size):
                if fitness[j] > fitness[i]:

                    r = np.linalg.norm(fireflies[i] - fireflies[j])
                    beta = beta0 * np.exp(-gamma * r * r)

                    random_step = alpha * (np.random.rand(num_features) - 0.5)

                    fireflies[i] = (
                        fireflies[i]
                        + beta * (fireflies[j] - fireflies[i])
                        + random_step
                    )

        fireflies = np.clip(fireflies, 0, 1)

        fitness_history.append(best_fitness)

        print(
            f"Generation {generation + 1}/{generations} | "
            f"Best FA Fitness: {best_fitness:.4f}"
        )

    selected_mask = (best_position > 0.5).astype(int)

    if np.sum(selected_mask) == 0:
        selected_mask[np.random.randint(0, num_features)] = 1

    return selected_mask, best_fitness, fitness_history


selected_mask, best_fa_fitness, fa_history = firefly_feature_selection(
    X_scaled,
    y
)

selected_feature_indices = np.where(selected_mask == 1)[0]
selected_features = [feature_cols[i] for i in selected_feature_indices]

print("\nSelected Features by FA:")
print(selected_features)

X_selected = X_scaled[:, selected_feature_indices]


# ============================================================
# Train-Test Split
# ============================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)


# ============================================================
# FA Optimized Random Forest Model
# ============================================================

fa_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

fa_model.fit(X_train, y_train)

y_pred = fa_model.predict(X_test)
fa_accuracy = accuracy_score(y_test, y_pred)

print("\nFA Optimized Random Forest Accuracy:", fa_accuracy)


# ============================================================
# H5 Deep Learning Model
# ============================================================

num_classes = len(np.unique(y))

y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

h5_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

h5_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = h5_model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_test, y_test_cat),
    epochs=50,
    batch_size=8,
    verbose=1
)

h5_loss, h5_accuracy = h5_model.evaluate(X_test, y_test_cat, verbose=0)


# ============================================================
# Result CSV
# ============================================================

result_df = pd.DataFrame([
    {
        "Model": "FA Optimized Random Forest",
        "Accuracy": fa_accuracy,
        "Fitness Score": best_fa_fitness,
        "Selected Features": ", ".join(selected_features)
    },
    {
        "Model": "FA Optimized H5 Neural Network",
        "Accuracy": h5_accuracy,
        "Fitness Score": best_fa_fitness,
        "Selected Features": ", ".join(selected_features)
    }
])

result_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "result.csv")
result_df.to_csv(result_csv_path, index=False)

print("\nResult CSV:")
print(result_df)


# ============================================================
# Prediction CSV
# ============================================================

final_pred_encoded = fa_model.predict(X_selected)

df["predicted_route_category"] = target_encoder.inverse_transform(
    final_pred_encoded
)

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction.csv")
df.to_csv(prediction_csv_path, index=False)

print("\nPrediction CSV Saved:", prediction_csv_path)


# ============================================================
# Graphs
# ============================================================

accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")
plt.figure(figsize=(8, 5))
plt.bar(result_df["Model"], result_df["Accuracy"])
plt.title("FA Model Accuracy Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(accuracy_graph_path)
plt.show()

comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")
plt.figure(figsize=(8, 5))
plt.plot(result_df["Model"], result_df["Accuracy"], marker="o")
plt.title("FA Model Comparison Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(comparison_graph_path)
plt.show()

heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")
corr_df = pd.DataFrame(X_selected, columns=selected_features)
corr_df["target"] = y
corr = corr_df.corr()

plt.figure(figsize=(10, 7))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("FA Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(heatmap_path)
plt.show()

result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")
plt.figure(figsize=(8, 5))
plt.barh(result_df["Model"], result_df["Accuracy"])
plt.title("FA Result Graph")
plt.xlabel("Accuracy")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(result_graph_path)
plt.show()

prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")
prediction_counts = df["predicted_route_category"].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(prediction_counts.index, prediction_counts.values)
plt.title("FA Prediction Category Distribution")
plt.xlabel("Predicted Route Category")
plt.ylabel("Count")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(prediction_graph_path)
plt.show()

optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(fa_history) + 1), fa_history, marker="o")
plt.title("FA Optimization Progress Graph")
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.grid(True)
plt.tight_layout()
plt.savefig(optimization_graph_path)
plt.show()

training_accuracy_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "training_accuracy_graph.png"
)

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("FA H5 Training Accuracy Graph")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(training_accuracy_graph_path)
plt.show()

cm = confusion_matrix(y_test, y_pred)

confusion_matrix_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "confusion_matrix_graph.png"
)

plt.figure(figsize=(7, 5))
plt.imshow(cm, interpolation="nearest")
plt.title("FA Confusion Matrix")
plt.colorbar()

classes = target_encoder.classes_

plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig(confusion_matrix_graph_path)
plt.show()


# ============================================================
# Save PKL Files
# ============================================================

model_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "model.pkl")
scaler_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")
encoder_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "encoders.pkl")
feature_selection_pkl_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "selected_features.pkl"
)

with open(model_pkl_path, "wb") as f:
    pickle.dump(fa_model, f)

with open(scaler_pkl_path, "wb") as f:
    pickle.dump(scaler, f)

with open(encoder_pkl_path, "wb") as f:
    pickle.dump(
        {
            "feature_encoders": label_encoders,
            "target_encoder": target_encoder
        },
        f
    )

with open(feature_selection_pkl_path, "wb") as f:
    pickle.dump(
        {
            "selected_mask": selected_mask,
            "selected_features": selected_features,
            "best_fitness": best_fa_fitness
        },
        f
    )


# ============================================================
# Save H5 Model
# ============================================================

h5_model_path = os.path.join(OUTPUT_DIR, PREFIX + "model.h5")
h5_model.save(h5_model_path)


# ============================================================
# Save YAML Config
# ============================================================

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

config = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Firefly Algorithm",
    "prefix": PREFIX,
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": "trade_route_category",
    "all_features": feature_cols,
    "selected_features": selected_features,
    "fa_parameters": {
        "population_size": 20,
        "generations": 25,
        "alpha": 0.2,
        "beta0": 1.0,
        "gamma": 1.0,
        "best_fitness": float(best_fa_fitness)
    },
    "files_generated": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(yaml_path, "w") as f:
    yaml.dump(config, f, default_flow_style=False)


# ============================================================
# Save JSON Results
# ============================================================

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

json_results = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Firefly Algorithm",
    "prefix": PREFIX,
    "fa_accuracy": float(fa_accuracy),
    "h5_accuracy": float(h5_accuracy),
    "best_fa_fitness": float(best_fa_fitness),
    "selected_features": selected_features,
    "model_results": result_df.to_dict(orient="records"),
    "classification_report": classification_report(
        y_test,
        y_pred,
        target_names=target_encoder.classes_,
        output_dict=True
    ),
    "confusion_matrix": cm.tolist(),
    "total_records": int(len(df)),
    "total_selected_features": int(len(selected_features)),
    "target_classes": list(target_encoder.classes_),
    "saved_files": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "yaml_config": yaml_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(json_path, "w") as f:
    json.dump(json_results, f, indent=4)


# ============================================================
# Final Output
# ============================================================

print("\nAll FA Files Saved Successfully")

print("\nCSV Files:")
print(result_csv_path)
print(prediction_csv_path)

print("\nModel Files:")
print(h5_model_path)
print(model_pkl_path)
print(scaler_pkl_path)
print(encoder_pkl_path)
print(feature_selection_pkl_path)

print("\nConfig Files:")
print(yaml_path)
print(json_path)

print("\nGraph Files:")
print(accuracy_graph_path)
print(comparison_graph_path)
print(heatmap_path)
print(result_graph_path)
print(prediction_graph_path)
print(optimization_graph_path)
print(training_accuracy_graph_path)
print(confusion_matrix_graph_path)

print("\nSelected Features:")
print(selected_features)

print("\nFA Accuracy:", fa_accuracy)
print("H5 Accuracy:", h5_accuracy)
print("Best FA Fitness:", best_fa_fitness)
# Out:
# Generation 1/25 | Best FA Fitness: 0.9956
# Generation 2/25 | Best FA Fitness: 0.9956
# Generation 3/25 | Best FA Fitness: 0.9956
# Generation 4/25 | Best FA Fitness: 0.9956
# Generation 5/25 | Best FA Fitness: 0.9956
# Generation 6/25 | Best FA Fitness: 0.9956
# Generation 7/25 | Best FA Fitness: 0.9956
# Generation 8/25 | Best FA Fitness: 0.9956
# Generation 9/25 | Best FA Fitness: 0.9956
# Generation 10/25 | Best FA Fitness: 0.9956
# Generation 11/25 | Best FA Fitness: 0.9956
# Generation 12/25 | Best FA Fitness: 0.9956
# Generation 13/25 | Best FA Fitness: 0.9956
# Generation 14/25 | Best FA Fitness: 0.9956
# Generation 15/25 | Best FA Fitness: 0.9956
# Generation 16/25 | Best FA Fitness: 0.9956
# Generation 17/25 | Best FA Fitness: 0.9956
# Generation 18/25 | Best FA Fitness: 0.9956
# Generation 19/25 | Best FA Fitness: 0.9956
# Generation 20/25 | Best FA Fitness: 0.9956
# Generation 21/25 | Best FA Fitness: 0.9956
# Generation 22/25 | Best FA Fitness: 0.9956
# Generation 23/25 | Best FA Fitness: 0.9956
# Generation 24/25 | Best FA Fitness: 0.9956
# Generation 25/25 | Best FA Fitness: 0.9956
#
# Selected Features by FA:
# ['District Name_encoded', 'Market Name_encoded', 'block_name_length', 'route_density_score']
#
# FA Optimized Random Forest Accuracy: 1.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.3673 - loss: 1.1031 - val_accuracy: 0.3846 - val_loss: 1.0233
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4490 - loss: 1.0352 - val_accuracy: 0.6154 - val_loss: 0.9657
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6122 - loss: 0.9727 - val_accuracy: 0.6923 - val_loss: 0.9097
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6939 - loss: 0.8934 - val_accuracy: 0.6923 - val_loss: 0.8625
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6531 - loss: 0.8918 - val_accuracy: 0.7692 - val_loss: 0.8230
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6939 - loss: 0.8302 - val_accuracy: 0.8462 - val_loss: 0.7844
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7959 - loss: 0.7767 - val_accuracy: 0.8462 - val_loss: 0.7525
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7755 - loss: 0.7823 - val_accuracy: 0.8462 - val_loss: 0.7244
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7959 - loss: 0.7030 - val_accuracy: 0.7692 - val_loss: 0.6995
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8571 - loss: 0.6735 - val_accuracy: 0.7692 - val_loss: 0.6764
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7959 - loss: 0.6417 - val_accuracy: 0.7692 - val_loss: 0.6583
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8163 - loss: 0.6103 - val_accuracy: 0.7692 - val_loss: 0.6380
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8163 - loss: 0.6073 - val_accuracy: 0.7692 - val_loss: 0.6177
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8367 - loss: 0.5452 - val_accuracy: 0.7692 - val_loss: 0.5974
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8367 - loss: 0.5405 - val_accuracy: 0.7692 - val_loss: 0.5804
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8776 - loss: 0.5183 - val_accuracy: 0.7692 - val_loss: 0.5634
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8163 - loss: 0.4690 - val_accuracy: 0.7692 - val_loss: 0.5535
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8776 - loss: 0.4460 - val_accuracy: 0.7692 - val_loss: 0.5500
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8980 - loss: 0.4207 - val_accuracy: 0.7692 - val_loss: 0.5447
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8571 - loss: 0.3889 - val_accuracy: 0.7692 - val_loss: 0.5385
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8776 - loss: 0.4148 - val_accuracy: 0.7692 - val_loss: 0.5241
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8367 - loss: 0.4134 - val_accuracy: 0.7692 - val_loss: 0.5119
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8571 - loss: 0.4194 - val_accuracy: 0.7692 - val_loss: 0.5075
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8980 - loss: 0.3351 - val_accuracy: 0.7692 - val_loss: 0.5053
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8571 - loss: 0.3613 - val_accuracy: 0.8462 - val_loss: 0.5120
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8980 - loss: 0.3224 - val_accuracy: 0.8462 - val_loss: 0.5228
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9184 - loss: 0.3136 - val_accuracy: 0.8462 - val_loss: 0.5268
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8776 - loss: 0.3512 - val_accuracy: 0.8462 - val_loss: 0.5201
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8776 - loss: 0.3578 - val_accuracy: 0.8462 - val_loss: 0.5151
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9184 - loss: 0.2899 - val_accuracy: 0.8462 - val_loss: 0.5070
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8571 - loss: 0.3558 - val_accuracy: 0.8462 - val_loss: 0.4987
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8776 - loss: 0.3374 - val_accuracy: 0.8462 - val_loss: 0.4928
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9592 - loss: 0.2546 - val_accuracy: 0.8462 - val_loss: 0.4957
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9796 - loss: 0.2276 - val_accuracy: 0.8462 - val_loss: 0.5048
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.2141 - val_accuracy: 0.8462 - val_loss: 0.5327
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9388 - loss: 0.2543 - val_accuracy: 0.8462 - val_loss: 0.5490
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9388 - loss: 0.2166 - val_accuracy: 0.7692 - val_loss: 0.5539
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8776 - loss: 0.2734 - val_accuracy: 0.7692 - val_loss: 0.5488
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9184 - loss: 0.2695 - val_accuracy: 0.7692 - val_loss: 0.5338
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9592 - loss: 0.2131 - val_accuracy: 0.7692 - val_loss: 0.5203
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8367 - loss: 0.2953 - val_accuracy: 0.8462 - val_loss: 0.5067
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9184 - loss: 0.2309 - val_accuracy: 0.8462 - val_loss: 0.5059
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8980 - loss: 0.2447 - val_accuracy: 0.8462 - val_loss: 0.5041
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9388 - loss: 0.2072 - val_accuracy: 0.8462 - val_loss: 0.5072
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9796 - loss: 0.1987 - val_accuracy: 0.8462 - val_loss: 0.5074
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.1910 - val_accuracy: 0.8462 - val_loss: 0.5021
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.2314 - val_accuracy: 0.8462 - val_loss: 0.5088
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.2156 - val_accuracy: 0.8462 - val_loss: 0.5121
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.1735 - val_accuracy: 0.8462 - val_loss: 0.5062
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9388 - loss: 0.2089 - val_accuracy: 0.8462 - val_loss: 0.5028
#
# Result CSV:
#                             Model  Accuracy  Fitness Score  \
# 0      FA Optimized Random Forest  1.000000       0.995556
# 1  FA Optimized H5 Neural Network  0.846154       0.995556
#
#                                    Selected Features
# 0  District Name_encoded, Market Name_encoded, bl...
# 1  District Name_encoded, Market Name_encoded, bl...
#
# Prediction CSV Saved: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_prediction.csv
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# All FA Files Saved Successfully
#
# CSV Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_result.csv
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_prediction.csv
#
# Model Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_model.h5
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_model.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_scaler.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_encoders.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_selected_features.pkl
#
# Config Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_config.yaml
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_results.json
#
# Graph Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_comparison_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_heatmap.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_result_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_prediction_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_optimization_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_training_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\fa_confusion_matrix_graph.png
#
# Selected Features:
# ['District Name_encoded', 'Market Name_encoded', 'block_name_length', 'route_density_score']
#
# FA Accuracy: 1.0
# H5 Accuracy: 0.8461538553237915
# Best FA Fitness: 0.9955555555555555
