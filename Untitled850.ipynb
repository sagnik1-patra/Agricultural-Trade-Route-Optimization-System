# %%
import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical


DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\megambmarketname_n.xls"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "ka_"


# ============================================================
# Load Dataset
# ============================================================

df = pd.read_excel(DATASET_PATH)
df.columns = df.columns.str.strip()

required_columns = ["District Name", "Block Name", "Market Name"]

for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"Missing required column: {col}")

df = df.dropna()
df = df.drop_duplicates()

for col in required_columns:
    df[col] = df[col].astype(str).str.strip()


# ============================================================
# Feature Engineering
# ============================================================

df["district_market_count"] = df.groupby("District Name")["Market Name"].transform("count")
df["block_market_count"] = df.groupby("Block Name")["Market Name"].transform("count")

df["market_name_length"] = df["Market Name"].apply(len)
df["block_name_length"] = df["Block Name"].apply(len)
df["district_name_length"] = df["District Name"].apply(len)

df["route_density_score"] = (
    df["district_market_count"] * 0.5 +
    df["block_market_count"] * 0.4 +
    df["market_name_length"] * 0.1
)

df["trade_route_category"] = pd.qcut(
    df["route_density_score"],
    q=3,
    labels=[
        "Low Route Priority",
        "Medium Route Priority",
        "High Route Priority"
    ],
    duplicates="drop"
)


# ============================================================
# Encoding
# ============================================================

label_encoders = {}

for col in required_columns:
    le = LabelEncoder()
    df[col + "_encoded"] = le.fit_transform(df[col])
    label_encoders[col] = le

target_encoder = LabelEncoder()
df["target"] = target_encoder.fit_transform(df["trade_route_category"])


# ============================================================
# Features and Target
# ============================================================

feature_cols = [
    "District Name_encoded",
    "Block Name_encoded",
    "Market Name_encoded",
    "district_market_count",
    "block_market_count",
    "market_name_length",
    "block_name_length",
    "district_name_length",
    "route_density_score"
]

X = df[feature_cols].values
y = df["target"].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# ============================================================
# KA Feature Selection
# Krill Herd Algorithm
# ============================================================

def fitness_function(mask, X_data, y_data):
    selected_features = np.where(mask == 1)[0]

    if len(selected_features) == 0:
        return 0

    X_selected = X_data[:, selected_features]

    X_train_fs, X_test_fs, y_train_fs, y_test_fs = train_test_split(
        X_selected,
        y_data,
        test_size=0.2,
        random_state=42,
        stratify=y_data
    )

    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=8,
        random_state=42
    )

    model.fit(X_train_fs, y_train_fs)
    pred = model.predict(X_test_fs)

    accuracy = accuracy_score(y_test_fs, pred)
    feature_penalty = len(selected_features) / X_data.shape[1]

    return accuracy - (0.01 * feature_penalty)


def krill_herd_feature_selection(
    X_data,
    y_data,
    population_size=20,
    generations=25,
    induced_speed=0.01,
    foraging_speed=0.02,
    diffusion_speed=0.005
):
    num_features = X_data.shape[1]

    krill = np.random.rand(population_size, num_features)
    fitness = np.zeros(population_size)

    best_position = None
    best_fitness = -np.inf
    fitness_history = []

    for generation in range(generations):

        for i in range(population_size):
            binary_krill = (krill[i] > 0.5).astype(int)

            if np.sum(binary_krill) == 0:
                binary_krill[np.random.randint(0, num_features)] = 1

            fitness[i] = fitness_function(binary_krill, X_data, y_data)

            if fitness[i] > best_fitness:
                best_fitness = fitness[i]
                best_position = krill[i].copy()

        worst_fitness = np.min(fitness)
        best_current_fitness = np.max(fitness)

        normalized_fitness = (
            (fitness - worst_fitness) /
            (best_current_fitness - worst_fitness + 1e-10)
        )

        new_krill = krill.copy()

        for i in range(population_size):
            neighbor_effect = np.zeros(num_features)

            for j in range(population_size):
                if i != j:
                    distance = np.linalg.norm(krill[j] - krill[i]) + 1e-10
                    direction = (krill[j] - krill[i]) / distance
                    attraction = normalized_fitness[j] - normalized_fitness[i]
                    neighbor_effect += attraction * direction

            neighbor_effect = induced_speed * neighbor_effect

            food_position = np.average(
                krill,
                axis=0,
                weights=normalized_fitness + 1e-10
            )

            foraging_motion = foraging_speed * (
                food_position - krill[i]
            )

            best_motion = foraging_speed * (
                best_position - krill[i]
            )

            random_diffusion = diffusion_speed * (
                np.random.rand(num_features) - 0.5
            )

            new_krill[i] = (
                krill[i]
                + neighbor_effect
                + foraging_motion
                + best_motion
                + random_diffusion
            )

        krill = np.clip(new_krill, 0, 1)

        fitness_history.append(best_fitness)

        print(
            f"Generation {generation + 1}/{generations} | "
            f"Best KA Fitness: {best_fitness:.4f}"
        )

    selected_mask = (best_position > 0.5).astype(int)

    if np.sum(selected_mask) == 0:
        selected_mask[np.random.randint(0, num_features)] = 1

    return selected_mask, best_fitness, fitness_history


selected_mask, best_ka_fitness, ka_history = krill_herd_feature_selection(
    X_scaled,
    y
)

selected_feature_indices = np.where(selected_mask == 1)[0]
selected_features = [feature_cols[i] for i in selected_feature_indices]

print("\nSelected Features by KA:")
print(selected_features)

X_selected = X_scaled[:, selected_feature_indices]


# ============================================================
# Train-Test Split
# ============================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)


# ============================================================
# KA Optimized Random Forest Model
# ============================================================

ka_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

ka_model.fit(X_train, y_train)

y_pred = ka_model.predict(X_test)
ka_accuracy = accuracy_score(y_test, y_pred)

print("\nKA Optimized Random Forest Accuracy:", ka_accuracy)


# ============================================================
# H5 Deep Learning Model
# ============================================================

num_classes = len(np.unique(y))

y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

h5_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

h5_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = h5_model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_test, y_test_cat),
    epochs=50,
    batch_size=8,
    verbose=1
)

h5_loss, h5_accuracy = h5_model.evaluate(X_test, y_test_cat, verbose=0)


# ============================================================
# Result CSV
# ============================================================

result_df = pd.DataFrame([
    {
        "Model": "KA Optimized Random Forest",
        "Accuracy": ka_accuracy,
        "Fitness Score": best_ka_fitness,
        "Selected Features": ", ".join(selected_features)
    },
    {
        "Model": "KA Optimized H5 Neural Network",
        "Accuracy": h5_accuracy,
        "Fitness Score": best_ka_fitness,
        "Selected Features": ", ".join(selected_features)
    }
])

result_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "result.csv")
result_df.to_csv(result_csv_path, index=False)

print("\nResult CSV:")
print(result_df)


# ============================================================
# Prediction CSV
# ============================================================

final_pred_encoded = ka_model.predict(X_selected)

df["predicted_route_category"] = target_encoder.inverse_transform(
    final_pred_encoded
)

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction.csv")
df.to_csv(prediction_csv_path, index=False)

print("\nPrediction CSV Saved:", prediction_csv_path)


# ============================================================
# Graphs
# ============================================================

accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")
plt.figure(figsize=(8, 5))
plt.bar(result_df["Model"], result_df["Accuracy"])
plt.title("KA Model Accuracy Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(accuracy_graph_path)
plt.show()

comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")
plt.figure(figsize=(8, 5))
plt.plot(result_df["Model"], result_df["Accuracy"], marker="o")
plt.title("KA Model Comparison Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(comparison_graph_path)
plt.show()

heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")
corr_df = pd.DataFrame(X_selected, columns=selected_features)
corr_df["target"] = y
corr = corr_df.corr()

plt.figure(figsize=(10, 7))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("KA Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(heatmap_path)
plt.show()

result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")
plt.figure(figsize=(8, 5))
plt.barh(result_df["Model"], result_df["Accuracy"])
plt.title("KA Result Graph")
plt.xlabel("Accuracy")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(result_graph_path)
plt.show()

prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")
prediction_counts = df["predicted_route_category"].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(prediction_counts.index, prediction_counts.values)
plt.title("KA Prediction Category Distribution")
plt.xlabel("Predicted Route Category")
plt.ylabel("Count")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(prediction_graph_path)
plt.show()

optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(ka_history) + 1), ka_history, marker="o")
plt.title("KA Optimization Progress Graph")
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.grid(True)
plt.tight_layout()
plt.savefig(optimization_graph_path)
plt.show()

training_accuracy_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "training_accuracy_graph.png"
)

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("KA H5 Training Accuracy Graph")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(training_accuracy_graph_path)
plt.show()

cm = confusion_matrix(y_test, y_pred)

confusion_matrix_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "confusion_matrix_graph.png"
)

plt.figure(figsize=(7, 5))
plt.imshow(cm, interpolation="nearest")
plt.title("KA Confusion Matrix")
plt.colorbar()

classes = target_encoder.classes_

plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig(confusion_matrix_graph_path)
plt.show()


# ============================================================
# Save PKL Files
# ============================================================

model_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "model.pkl")
scaler_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")
encoder_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "encoders.pkl")
feature_selection_pkl_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "selected_features.pkl"
)

with open(model_pkl_path, "wb") as f:
    pickle.dump(ka_model, f)

with open(scaler_pkl_path, "wb") as f:
    pickle.dump(scaler, f)

with open(encoder_pkl_path, "wb") as f:
    pickle.dump(
        {
            "feature_encoders": label_encoders,
            "target_encoder": target_encoder
        },
        f
    )

with open(feature_selection_pkl_path, "wb") as f:
    pickle.dump(
        {
            "selected_mask": selected_mask,
            "selected_features": selected_features,
            "best_fitness": best_ka_fitness
        },
        f
    )


# ============================================================
# Save H5 Model
# ============================================================

h5_model_path = os.path.join(OUTPUT_DIR, PREFIX + "model.h5")
h5_model.save(h5_model_path)


# ============================================================
# Save YAML Config
# ============================================================

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

config = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Krill Herd Algorithm",
    "prefix": PREFIX,
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": "trade_route_category",
    "all_features": feature_cols,
    "selected_features": selected_features,
    "ka_parameters": {
        "population_size": 20,
        "generations": 25,
        "induced_speed": 0.01,
        "foraging_speed": 0.02,
        "diffusion_speed": 0.005,
        "best_fitness": float(best_ka_fitness)
    },
    "files_generated": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(yaml_path, "w") as f:
    yaml.dump(config, f, default_flow_style=False)


# ============================================================
# Save JSON Results
# ============================================================

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

json_results = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Krill Herd Algorithm",
    "prefix": PREFIX,
    "ka_accuracy": float(ka_accuracy),
    "h5_accuracy": float(h5_accuracy),
    "best_ka_fitness": float(best_ka_fitness),
    "selected_features": selected_features,
    "model_results": result_df.to_dict(orient="records"),
    "classification_report": classification_report(
        y_test,
        y_pred,
        target_names=target_encoder.classes_,
        output_dict=True
    ),
    "confusion_matrix": cm.tolist(),
    "total_records": int(len(df)),
    "total_selected_features": int(len(selected_features)),
    "target_classes": list(target_encoder.classes_),
    "saved_files": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "yaml_config": yaml_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(json_path, "w") as f:
    json.dump(json_results, f, indent=4)


print("\nAll KA Files Saved Successfully")
print("Result CSV:", result_csv_path)
print("Prediction CSV:", prediction_csv_path)
print("H5 Model:", h5_model_path)
print("PKL Model:", model_pkl_path)
print("YAML:", yaml_path)
print("JSON:", json_path)
print("KA Accuracy:", ka_accuracy)
print("H5 Accuracy:", h5_accuracy)
print("Best KA Fitness:", best_ka_fitness)
# Out:
# Generation 1/25 | Best KA Fitness: 0.9967
# Generation 2/25 | Best KA Fitness: 0.9967
# Generation 3/25 | Best KA Fitness: 0.9967
# Generation 4/25 | Best KA Fitness: 0.9967
# Generation 5/25 | Best KA Fitness: 0.9967
# Generation 6/25 | Best KA Fitness: 0.9967
# Generation 7/25 | Best KA Fitness: 0.9967
# Generation 8/25 | Best KA Fitness: 0.9967
# Generation 9/25 | Best KA Fitness: 0.9967
# Generation 10/25 | Best KA Fitness: 0.9967
# Generation 11/25 | Best KA Fitness: 0.9967
# Generation 12/25 | Best KA Fitness: 0.9989
# Generation 13/25 | Best KA Fitness: 0.9989
# Generation 14/25 | Best KA Fitness: 0.9989
# Generation 15/25 | Best KA Fitness: 0.9989
# Generation 16/25 | Best KA Fitness: 0.9989
# Generation 17/25 | Best KA Fitness: 0.9989
# Generation 18/25 | Best KA Fitness: 0.9989
# Generation 19/25 | Best KA Fitness: 0.9989
# Generation 20/25 | Best KA Fitness: 0.9989
# Generation 21/25 | Best KA Fitness: 0.9989
# Generation 22/25 | Best KA Fitness: 0.9989
# Generation 23/25 | Best KA Fitness: 0.9989
# Generation 24/25 | Best KA Fitness: 0.9989
# Generation 25/25 | Best KA Fitness: 0.9989
#
# Selected Features by KA:
# ['route_density_score']
#
# KA Optimized Random Forest Accuracy: 1.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.4082 - loss: 1.0343 - val_accuracy: 0.6923 - val_loss: 0.9586
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5918 - loss: 0.9692 - val_accuracy: 0.6923 - val_loss: 0.9000
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6531 - loss: 0.9426 - val_accuracy: 0.6923 - val_loss: 0.8503
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7143 - loss: 0.8734 - val_accuracy: 0.6923 - val_loss: 0.8083
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6531 - loss: 0.8279 - val_accuracy: 0.6923 - val_loss: 0.7723
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6531 - loss: 0.8177 - val_accuracy: 0.6923 - val_loss: 0.7393
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6531 - loss: 0.7840 - val_accuracy: 0.6923 - val_loss: 0.7058
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6735 - loss: 0.7156 - val_accuracy: 0.6923 - val_loss: 0.6706
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6531 - loss: 0.6894 - val_accuracy: 0.6923 - val_loss: 0.6414
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6531 - loss: 0.6842 - val_accuracy: 0.6923 - val_loss: 0.6145
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7143 - loss: 0.6392 - val_accuracy: 0.7692 - val_loss: 0.5858
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6531 - loss: 0.6312 - val_accuracy: 0.7692 - val_loss: 0.5621
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7551 - loss: 0.5858 - val_accuracy: 0.7692 - val_loss: 0.5385
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7143 - loss: 0.5868 - val_accuracy: 0.7692 - val_loss: 0.5158
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7755 - loss: 0.5549 - val_accuracy: 0.7692 - val_loss: 0.4920
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8163 - loss: 0.5266 - val_accuracy: 0.8462 - val_loss: 0.4719
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8163 - loss: 0.5141 - val_accuracy: 0.8462 - val_loss: 0.4507
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8163 - loss: 0.4798 - val_accuracy: 0.8462 - val_loss: 0.4383
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8571 - loss: 0.4628 - val_accuracy: 0.8462 - val_loss: 0.4230
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7959 - loss: 0.4510 - val_accuracy: 0.8462 - val_loss: 0.4096
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8163 - loss: 0.4431 - val_accuracy: 0.8462 - val_loss: 0.3905
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8571 - loss: 0.4429 - val_accuracy: 0.8462 - val_loss: 0.3736
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8776 - loss: 0.4267 - val_accuracy: 0.8462 - val_loss: 0.3597
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8571 - loss: 0.4339 - val_accuracy: 0.8462 - val_loss: 0.3449
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8776 - loss: 0.3983 - val_accuracy: 0.8462 - val_loss: 0.3256
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8776 - loss: 0.3559 - val_accuracy: 0.8462 - val_loss: 0.3140
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9796 - loss: 0.3435 - val_accuracy: 0.8462 - val_loss: 0.2999
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8776 - loss: 0.3476 - val_accuracy: 0.8462 - val_loss: 0.2890
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.3121 - val_accuracy: 0.8462 - val_loss: 0.2799
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8980 - loss: 0.3289 - val_accuracy: 0.8462 - val_loss: 0.2746
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.3291 - val_accuracy: 0.8462 - val_loss: 0.2674
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9388 - loss: 0.2957 - val_accuracy: 0.8462 - val_loss: 0.2617
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9184 - loss: 0.3044 - val_accuracy: 0.8462 - val_loss: 0.2489
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8980 - loss: 0.2876 - val_accuracy: 0.8462 - val_loss: 0.2430
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9592 - loss: 0.2584 - val_accuracy: 0.8462 - val_loss: 0.2326
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8980 - loss: 0.2508 - val_accuracy: 1.0000 - val_loss: 0.2214
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.2363 - val_accuracy: 1.0000 - val_loss: 0.2149
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.2383 - val_accuracy: 1.0000 - val_loss: 0.2095
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8980 - loss: 0.2303 - val_accuracy: 1.0000 - val_loss: 0.2038
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9388 - loss: 0.2314 - val_accuracy: 1.0000 - val_loss: 0.1998
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8980 - loss: 0.2487 - val_accuracy: 1.0000 - val_loss: 0.1977
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8776 - loss: 0.2399 - val_accuracy: 1.0000 - val_loss: 0.1959
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9388 - loss: 0.2248 - val_accuracy: 1.0000 - val_loss: 0.1916
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9592 - loss: 0.2382 - val_accuracy: 1.0000 - val_loss: 0.1841
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.2081 - val_accuracy: 1.0000 - val_loss: 0.1811
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.1991 - val_accuracy: 1.0000 - val_loss: 0.1774
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9388 - loss: 0.1907 - val_accuracy: 1.0000 - val_loss: 0.1753
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9184 - loss: 0.2246 - val_accuracy: 1.0000 - val_loss: 0.1741
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.2240 - val_accuracy: 1.0000 - val_loss: 0.1702
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9388 - loss: 0.1743 - val_accuracy: 1.0000 - val_loss: 0.1668
#
# Result CSV:
#                             Model  Accuracy  Fitness Score  \
# 0      KA Optimized Random Forest       1.0       0.998889
# 1  KA Optimized H5 Neural Network       1.0       0.998889
#
#      Selected Features
# 0  route_density_score
# 1  route_density_score
#
# Prediction CSV Saved: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_prediction.csv
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# All KA Files Saved Successfully
# Result CSV: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_result.csv
# Prediction CSV: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_prediction.csv
# H5 Model: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_model.h5
# PKL Model: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_model.pkl
# YAML: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_config.yaml
# JSON: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\ka_results.json
# KA Accuracy: 1.0
# H5 Accuracy: 1.0
# Best KA Fitness: 0.9988888888888889
