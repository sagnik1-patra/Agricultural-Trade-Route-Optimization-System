# %%
import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical


# ============================================================
# Paths
# ============================================================

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\megambmarketname_n.xls"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "csa_"


# ============================================================
# Load Dataset
# ============================================================

df = pd.read_excel(DATASET_PATH)
df.columns = df.columns.str.strip()

required_columns = ["District Name", "Block Name", "Market Name"]

for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"Missing required column: {col}")

df = df.dropna()
df = df.drop_duplicates()

for col in required_columns:
    df[col] = df[col].astype(str).str.strip()


# ============================================================
# Feature Engineering
# ============================================================

df["district_market_count"] = df.groupby("District Name")["Market Name"].transform("count")
df["block_market_count"] = df.groupby("Block Name")["Market Name"].transform("count")

df["market_name_length"] = df["Market Name"].apply(len)
df["block_name_length"] = df["Block Name"].apply(len)
df["district_name_length"] = df["District Name"].apply(len)

df["route_density_score"] = (
    df["district_market_count"] * 0.5 +
    df["block_market_count"] * 0.4 +
    df["market_name_length"] * 0.1
)

df["trade_route_category"] = pd.qcut(
    df["route_density_score"],
    q=3,
    labels=[
        "Low Route Priority",
        "Medium Route Priority",
        "High Route Priority"
    ],
    duplicates="drop"
)


# ============================================================
# Encoding
# ============================================================

label_encoders = {}

for col in required_columns:
    le = LabelEncoder()
    df[col + "_encoded"] = le.fit_transform(df[col])
    label_encoders[col] = le

target_encoder = LabelEncoder()
df["target"] = target_encoder.fit_transform(df["trade_route_category"])


# ============================================================
# Features and Target
# ============================================================

feature_cols = [
    "District Name_encoded",
    "Block Name_encoded",
    "Market Name_encoded",
    "district_market_count",
    "block_market_count",
    "market_name_length",
    "block_name_length",
    "district_name_length",
    "route_density_score"
]

X = df[feature_cols].values
y = df["target"].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# ============================================================
# CSA Feature Selection
# Clonal Selection Algorithm
# ============================================================

def fitness_function(mask, X_data, y_data):
    selected_features = np.where(mask == 1)[0]

    if len(selected_features) == 0:
        return 0

    X_selected = X_data[:, selected_features]

    X_train_fs, X_test_fs, y_train_fs, y_test_fs = train_test_split(
        X_selected,
        y_data,
        test_size=0.2,
        random_state=42,
        stratify=y_data
    )

    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=8,
        random_state=42
    )

    model.fit(X_train_fs, y_train_fs)
    pred = model.predict(X_test_fs)

    accuracy = accuracy_score(y_test_fs, pred)
    feature_penalty = len(selected_features) / X_data.shape[1]

    fitness = accuracy - (0.01 * feature_penalty)

    return fitness


def csa_feature_selection(
    X_data,
    y_data,
    population_size=20,
    generations=25,
    clone_rate=5,
    mutation_rate=0.15,
    replacement_rate=0.3
):
    num_features = X_data.shape[1]

    population = np.random.randint(
        0,
        2,
        size=(population_size, num_features)
    )

    for i in range(population_size):
        if np.sum(population[i]) == 0:
            population[i, np.random.randint(0, num_features)] = 1

    best_solution = None
    best_fitness = -1
    fitness_history = []

    for generation in range(generations):
        fitness_scores = np.array([
            fitness_function(individual, X_data, y_data)
            for individual in population
        ])

        sorted_indices = np.argsort(fitness_scores)[::-1]
        population = population[sorted_indices]
        fitness_scores = fitness_scores[sorted_indices]

        if fitness_scores[0] > best_fitness:
            best_fitness = fitness_scores[0]
            best_solution = population[0].copy()

        elite_count = population_size // 2
        elites = population[:elite_count]

        clones = []

        for rank, antibody in enumerate(elites):
            num_clones = max(1, clone_rate * (elite_count - rank))

            for _ in range(num_clones):
                clone = antibody.copy()

                adaptive_mutation = mutation_rate * (1 - fitness_scores[rank])

                mutation_mask = np.random.rand(num_features) < adaptive_mutation
                clone[mutation_mask] = 1 - clone[mutation_mask]

                if np.sum(clone) == 0:
                    clone[np.random.randint(0, num_features)] = 1

                clones.append(clone)

        clone_fitness = np.array([
            fitness_function(clone, X_data, y_data)
            for clone in clones
        ])

        best_clone_indices = np.argsort(clone_fitness)[::-1]
        best_clones = np.array(clones)[best_clone_indices[:elite_count]]

        replace_count = int(population_size * replacement_rate)

        new_random = np.random.randint(
            0,
            2,
            size=(replace_count, num_features)
        )

        for i in range(replace_count):
            if np.sum(new_random[i]) == 0:
                new_random[i, np.random.randint(0, num_features)] = 1

        remaining_count = population_size - elite_count - replace_count

        population = np.vstack([
            best_clones,
            population[:remaining_count],
            new_random
        ])

        fitness_history.append(best_fitness)

        print(
            f"Generation {generation + 1}/{generations} | "
            f"Best CSA Fitness: {best_fitness:.4f}"
        )

    return best_solution, best_fitness, fitness_history


selected_mask, best_csa_fitness, csa_history = csa_feature_selection(
    X_scaled,
    y
)

selected_feature_indices = np.where(selected_mask == 1)[0]
selected_features = [feature_cols[i] for i in selected_feature_indices]

print("\nSelected Features by CSA:")
print(selected_features)

X_selected = X_scaled[:, selected_feature_indices]


# ============================================================
# Train-Test Split
# ============================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)


# ============================================================
# CSA Optimized Random Forest Model
# ============================================================

csa_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

csa_model.fit(X_train, y_train)

y_pred = csa_model.predict(X_test)

csa_accuracy = accuracy_score(y_test, y_pred)

print("\nCSA Optimized Random Forest Accuracy:", csa_accuracy)


# ============================================================
# H5 Deep Learning Model
# ============================================================

num_classes = len(np.unique(y))

y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

h5_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

h5_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = h5_model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_test, y_test_cat),
    epochs=50,
    batch_size=8,
    verbose=1
)

h5_loss, h5_accuracy = h5_model.evaluate(X_test, y_test_cat, verbose=0)


# ============================================================
# Result CSV
# ============================================================

result_df = pd.DataFrame([
    {
        "Model": "CSA Optimized Random Forest",
        "Accuracy": csa_accuracy,
        "Fitness Score": best_csa_fitness,
        "Selected Features": ", ".join(selected_features)
    },
    {
        "Model": "CSA Optimized H5 Neural Network",
        "Accuracy": h5_accuracy,
        "Fitness Score": best_csa_fitness,
        "Selected Features": ", ".join(selected_features)
    }
])

result_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "result.csv")
result_df.to_csv(result_csv_path, index=False)

print("\nResult CSV:")
print(result_df)


# ============================================================
# Prediction CSV
# ============================================================

final_pred_encoded = csa_model.predict(X_selected)

df["predicted_route_category"] = target_encoder.inverse_transform(final_pred_encoded)

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction.csv")
df.to_csv(prediction_csv_path, index=False)

print("\nPrediction CSV Saved:", prediction_csv_path)


# ============================================================
# Accuracy Graph
# ============================================================

accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")

plt.figure(figsize=(8, 5))
plt.bar(result_df["Model"], result_df["Accuracy"])
plt.title("CSA Model Accuracy Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(accuracy_graph_path)
plt.show()


# ============================================================
# Comparison Graph
# ============================================================

comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")

plt.figure(figsize=(8, 5))
plt.plot(result_df["Model"], result_df["Accuracy"], marker="o")
plt.title("CSA Model Comparison Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(comparison_graph_path)
plt.show()


# ============================================================
# Heatmap
# ============================================================

heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")

corr_df = pd.DataFrame(X_selected, columns=selected_features)
corr_df["target"] = y

corr = corr_df.corr()

plt.figure(figsize=(10, 7))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("CSA Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(heatmap_path)
plt.show()


# ============================================================
# Result Graph
# ============================================================

result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")

plt.figure(figsize=(8, 5))
plt.barh(result_df["Model"], result_df["Accuracy"])
plt.title("CSA Result Graph")
plt.xlabel("Accuracy")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(result_graph_path)
plt.show()


# ============================================================
# Prediction Graph
# ============================================================

prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")

prediction_counts = df["predicted_route_category"].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(prediction_counts.index, prediction_counts.values)
plt.title("CSA Prediction Category Distribution")
plt.xlabel("Predicted Route Category")
plt.ylabel("Count")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(prediction_graph_path)
plt.show()


# ============================================================
# CSA Optimization Progress Graph
# ============================================================

optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(csa_history) + 1), csa_history, marker="o")
plt.title("CSA Optimization Progress Graph")
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.grid(True)
plt.tight_layout()
plt.savefig(optimization_graph_path)
plt.show()


# ============================================================
# H5 Training Accuracy Graph
# ============================================================

training_accuracy_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "training_accuracy_graph.png"
)

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("CSA H5 Training Accuracy Graph")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(training_accuracy_graph_path)
plt.show()


# ============================================================
# Confusion Matrix Graph
# ============================================================

cm = confusion_matrix(y_test, y_pred)

confusion_matrix_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "confusion_matrix_graph.png"
)

plt.figure(figsize=(7, 5))
plt.imshow(cm, interpolation="nearest")
plt.title("CSA Confusion Matrix")
plt.colorbar()

classes = target_encoder.classes_

plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig(confusion_matrix_graph_path)
plt.show()


# ============================================================
# Save PKL Files
# ============================================================

model_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "model.pkl")
scaler_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")
encoder_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "encoders.pkl")
feature_selection_pkl_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "selected_features.pkl"
)

with open(model_pkl_path, "wb") as f:
    pickle.dump(csa_model, f)

with open(scaler_pkl_path, "wb") as f:
    pickle.dump(scaler, f)

with open(encoder_pkl_path, "wb") as f:
    pickle.dump(
        {
            "feature_encoders": label_encoders,
            "target_encoder": target_encoder
        },
        f
    )

with open(feature_selection_pkl_path, "wb") as f:
    pickle.dump(
        {
            "selected_mask": selected_mask,
            "selected_features": selected_features,
            "best_fitness": best_csa_fitness
        },
        f
    )


# ============================================================
# Save H5 Model
# ============================================================

h5_model_path = os.path.join(OUTPUT_DIR, PREFIX + "model.h5")
h5_model.save(h5_model_path)


# ============================================================
# Save YAML Config
# ============================================================

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

config = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Clonal Selection Algorithm",
    "prefix": PREFIX,
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": "trade_route_category",
    "all_features": feature_cols,
    "selected_features": selected_features,
    "csa_parameters": {
        "population_size": 20,
        "generations": 25,
        "clone_rate": 5,
        "mutation_rate": 0.15,
        "replacement_rate": 0.3,
        "best_fitness": float(best_csa_fitness)
    },
    "files_generated": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(yaml_path, "w") as f:
    yaml.dump(config, f, default_flow_style=False)


# ============================================================
# Save JSON Results
# ============================================================

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

json_results = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Clonal Selection Algorithm",
    "prefix": PREFIX,
    "csa_accuracy": float(csa_accuracy),
    "h5_accuracy": float(h5_accuracy),
    "best_csa_fitness": float(best_csa_fitness),
    "selected_features": selected_features,
    "model_results": result_df.to_dict(orient="records"),
    "classification_report": classification_report(
        y_test,
        y_pred,
        target_names=target_encoder.classes_,
        output_dict=True
    ),
    "confusion_matrix": cm.tolist(),
    "total_records": int(len(df)),
    "total_selected_features": int(len(selected_features)),
    "target_classes": list(target_encoder.classes_),
    "saved_files": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "yaml_config": yaml_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(json_path, "w") as f:
    json.dump(json_results, f, indent=4)


# ============================================================
# Final Output
# ============================================================

print("\nAll CSA Files Saved Successfully")

print("\nCSV Files:")
print(result_csv_path)
print(prediction_csv_path)

print("\nModel Files:")
print(h5_model_path)
print(model_pkl_path)
print(scaler_pkl_path)
print(encoder_pkl_path)
print(feature_selection_pkl_path)

print("\nConfig Files:")
print(yaml_path)
print(json_path)

print("\nGraph Files:")
print(accuracy_graph_path)
print(comparison_graph_path)
print(heatmap_path)
print(result_graph_path)
print(prediction_graph_path)
print(optimization_graph_path)
print(training_accuracy_graph_path)
print(confusion_matrix_graph_path)

print("\nSelected Features:")
print(selected_features)

print("\nCSA Accuracy:", csa_accuracy)
print("H5 Accuracy:", h5_accuracy)
print("Best CSA Fitness:", best_csa_fitness)
# Out:
# Generation 1/25 | Best CSA Fitness: 0.9186
# Generation 2/25 | Best CSA Fitness: 0.9944
# Generation 3/25 | Best CSA Fitness: 0.9956
# Generation 4/25 | Best CSA Fitness: 0.9956
# Generation 5/25 | Best CSA Fitness: 0.9956
# Generation 6/25 | Best CSA Fitness: 0.9956
# Generation 7/25 | Best CSA Fitness: 0.9956
# Generation 8/25 | Best CSA Fitness: 0.9956
# Generation 9/25 | Best CSA Fitness: 0.9956
# Generation 10/25 | Best CSA Fitness: 0.9956
# Generation 11/25 | Best CSA Fitness: 0.9956
# Generation 12/25 | Best CSA Fitness: 0.9967
# Generation 13/25 | Best CSA Fitness: 0.9967
# Generation 14/25 | Best CSA Fitness: 0.9967
# Generation 15/25 | Best CSA Fitness: 0.9967
# Generation 16/25 | Best CSA Fitness: 0.9967
# Generation 17/25 | Best CSA Fitness: 0.9967
# Generation 18/25 | Best CSA Fitness: 0.9978
# Generation 19/25 | Best CSA Fitness: 0.9978
# Generation 20/25 | Best CSA Fitness: 0.9978
# Generation 21/25 | Best CSA Fitness: 0.9978
# Generation 22/25 | Best CSA Fitness: 0.9989
# Generation 23/25 | Best CSA Fitness: 0.9989
# Generation 24/25 | Best CSA Fitness: 0.9989
# Generation 25/25 | Best CSA Fitness: 0.9989
#
# Selected Features by CSA:
# ['route_density_score']
#
# CSA Optimized Random Forest Accuracy: 1.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6122 - loss: 1.0004 - val_accuracy: 0.7692 - val_loss: 0.9040
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6735 - loss: 0.9200 - val_accuracy: 0.6923 - val_loss: 0.8436
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6735 - loss: 0.8714 - val_accuracy: 0.6923 - val_loss: 0.7901
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7143 - loss: 0.8299 - val_accuracy: 0.7692 - val_loss: 0.7435
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7143 - loss: 0.7684 - val_accuracy: 0.7692 - val_loss: 0.6997
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6939 - loss: 0.7552 - val_accuracy: 0.7692 - val_loss: 0.6656
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7347 - loss: 0.7205 - val_accuracy: 0.7692 - val_loss: 0.6316
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6939 - loss: 0.6910 - val_accuracy: 0.7692 - val_loss: 0.6016
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7143 - loss: 0.6545 - val_accuracy: 0.7692 - val_loss: 0.5785
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7143 - loss: 0.6172 - val_accuracy: 0.7692 - val_loss: 0.5587
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7347 - loss: 0.5999 - val_accuracy: 0.7692 - val_loss: 0.5394
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7755 - loss: 0.5967 - val_accuracy: 0.8462 - val_loss: 0.5176
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7959 - loss: 0.5796 - val_accuracy: 0.8462 - val_loss: 0.4964
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8163 - loss: 0.5675 - val_accuracy: 0.8462 - val_loss: 0.4799
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7755 - loss: 0.5316 - val_accuracy: 0.8462 - val_loss: 0.4642
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8367 - loss: 0.4977 - val_accuracy: 0.8462 - val_loss: 0.4475
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7959 - loss: 0.5212 - val_accuracy: 0.8462 - val_loss: 0.4304
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7959 - loss: 0.4672 - val_accuracy: 0.8462 - val_loss: 0.4153
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8367 - loss: 0.4453 - val_accuracy: 0.8462 - val_loss: 0.3985
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8980 - loss: 0.4478 - val_accuracy: 0.8462 - val_loss: 0.3878
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8367 - loss: 0.4021 - val_accuracy: 0.8462 - val_loss: 0.3777
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8980 - loss: 0.4291 - val_accuracy: 0.8462 - val_loss: 0.3682
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8776 - loss: 0.3782 - val_accuracy: 0.8462 - val_loss: 0.3590
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8980 - loss: 0.3621 - val_accuracy: 0.8462 - val_loss: 0.3516
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8980 - loss: 0.3616 - val_accuracy: 0.8462 - val_loss: 0.3399
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8980 - loss: 0.3584 - val_accuracy: 0.8462 - val_loss: 0.3280
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8776 - loss: 0.3374 - val_accuracy: 0.8462 - val_loss: 0.3117
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9388 - loss: 0.3151 - val_accuracy: 0.8462 - val_loss: 0.2815
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9184 - loss: 0.3081 - val_accuracy: 1.0000 - val_loss: 0.2734
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9388 - loss: 0.2987 - val_accuracy: 1.0000 - val_loss: 0.2582
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9184 - loss: 0.2994 - val_accuracy: 1.0000 - val_loss: 0.2468
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8980 - loss: 0.2843 - val_accuracy: 1.0000 - val_loss: 0.2405
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9184 - loss: 0.2538 - val_accuracy: 1.0000 - val_loss: 0.2335
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9796 - loss: 0.2395 - val_accuracy: 1.0000 - val_loss: 0.2260
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9388 - loss: 0.2233 - val_accuracy: 1.0000 - val_loss: 0.2188
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8980 - loss: 0.2445 - val_accuracy: 1.0000 - val_loss: 0.2100
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9592 - loss: 0.2002 - val_accuracy: 1.0000 - val_loss: 0.2016
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9184 - loss: 0.2201 - val_accuracy: 1.0000 - val_loss: 0.1964
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9796 - loss: 0.2110 - val_accuracy: 1.0000 - val_loss: 0.1903
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8776 - loss: 0.2392 - val_accuracy: 1.0000 - val_loss: 0.1860
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9388 - loss: 0.2471 - val_accuracy: 1.0000 - val_loss: 0.1828
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9592 - loss: 0.2182 - val_accuracy: 1.0000 - val_loss: 0.1805
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9592 - loss: 0.2057 - val_accuracy: 1.0000 - val_loss: 0.1811
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9184 - loss: 0.2378 - val_accuracy: 1.0000 - val_loss: 0.1817
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9592 - loss: 0.1850 - val_accuracy: 1.0000 - val_loss: 0.1753
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9388 - loss: 0.1768 - val_accuracy: 1.0000 - val_loss: 0.1659
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9184 - loss: 0.1859 - val_accuracy: 1.0000 - val_loss: 0.1628
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.1854 - val_accuracy: 1.0000 - val_loss: 0.1627
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9184 - loss: 0.1904 - val_accuracy: 1.0000 - val_loss: 0.1599
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.1707 - val_accuracy: 1.0000 - val_loss: 0.1587
#
# Result CSV:
#                              Model  Accuracy  Fitness Score  \
# 0      CSA Optimized Random Forest       1.0       0.998889
# 1  CSA Optimized H5 Neural Network       1.0       0.998889
#
#      Selected Features
# 0  route_density_score
# 1  route_density_score
#
# Prediction CSV Saved: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_prediction.csv
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# All CSA Files Saved Successfully
#
# CSV Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_result.csv
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_prediction.csv
#
# Model Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_model.h5
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_model.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_scaler.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_encoders.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_selected_features.pkl
#
# Config Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_config.yaml
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_results.json
#
# Graph Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_comparison_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_heatmap.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_result_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_prediction_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_optimization_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_training_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\csa_confusion_matrix_graph.png
#
# Selected Features:
# ['route_density_score']
#
# CSA Accuracy: 1.0
# H5 Accuracy: 1.0
# Best CSA Fitness: 0.9988888888888889
