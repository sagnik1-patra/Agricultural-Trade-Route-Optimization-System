# %%
import os
import json
import yaml
import pickle
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical


# ============================================================
# Paths
# ============================================================

DATASET_PATH = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\megambmarketname_n.xls"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

PREFIX = "pso_"


# ============================================================
# Load Dataset
# ============================================================

df = pd.read_excel(DATASET_PATH)
df.columns = df.columns.str.strip()

required_columns = ["District Name", "Block Name", "Market Name"]

for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"Missing required column: {col}")

df = df.dropna()
df = df.drop_duplicates()

for col in required_columns:
    df[col] = df[col].astype(str).str.strip()


# ============================================================
# Feature Engineering
# ============================================================

df["district_market_count"] = df.groupby("District Name")["Market Name"].transform("count")
df["block_market_count"] = df.groupby("Block Name")["Market Name"].transform("count")

df["market_name_length"] = df["Market Name"].apply(len)
df["block_name_length"] = df["Block Name"].apply(len)
df["district_name_length"] = df["District Name"].apply(len)

df["route_density_score"] = (
    df["district_market_count"] * 0.5 +
    df["block_market_count"] * 0.4 +
    df["market_name_length"] * 0.1
)

df["trade_route_category"] = pd.qcut(
    df["route_density_score"],
    q=3,
    labels=[
        "Low Route Priority",
        "Medium Route Priority",
        "High Route Priority"
    ],
    duplicates="drop"
)


# ============================================================
# Encoding
# ============================================================

label_encoders = {}

for col in required_columns:
    le = LabelEncoder()
    df[col + "_encoded"] = le.fit_transform(df[col])
    label_encoders[col] = le

target_encoder = LabelEncoder()
df["target"] = target_encoder.fit_transform(df["trade_route_category"])


# ============================================================
# Features and Target
# ============================================================

feature_cols = [
    "District Name_encoded",
    "Block Name_encoded",
    "Market Name_encoded",
    "district_market_count",
    "block_market_count",
    "market_name_length",
    "block_name_length",
    "district_name_length",
    "route_density_score"
]

X = df[feature_cols].values
y = df["target"].values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# ============================================================
# PSO Feature Selection
# ============================================================

def fitness_function(mask, X_data, y_data):
    selected_features = np.where(mask == 1)[0]

    if len(selected_features) == 0:
        return 0

    X_selected = X_data[:, selected_features]

    X_train_fs, X_test_fs, y_train_fs, y_test_fs = train_test_split(
        X_selected,
        y_data,
        test_size=0.2,
        random_state=42,
        stratify=y_data
    )

    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=8,
        random_state=42
    )

    model.fit(X_train_fs, y_train_fs)
    pred = model.predict(X_test_fs)

    accuracy = accuracy_score(y_test_fs, pred)
    feature_penalty = len(selected_features) / X_data.shape[1]

    return accuracy - (0.01 * feature_penalty)


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def pso_feature_selection(
    X_data,
    y_data,
    population_size=20,
    generations=25,
    w=0.7,
    c1=1.5,
    c2=1.5
):
    num_features = X_data.shape[1]

    position = np.random.randint(0, 2, size=(population_size, num_features))
    velocity = np.random.uniform(-1, 1, size=(population_size, num_features))

    for i in range(population_size):
        if np.sum(position[i]) == 0:
            position[i, np.random.randint(0, num_features)] = 1

    personal_best_position = position.copy()
    personal_best_score = np.array([
        fitness_function(p, X_data, y_data) for p in position
    ])

    global_best_index = np.argmax(personal_best_score)
    global_best_position = personal_best_position[global_best_index].copy()
    global_best_score = personal_best_score[global_best_index]

    fitness_history = []

    for generation in range(generations):
        for i in range(population_size):
            r1 = np.random.rand(num_features)
            r2 = np.random.rand(num_features)

            velocity[i] = (
                w * velocity[i]
                + c1 * r1 * (personal_best_position[i] - position[i])
                + c2 * r2 * (global_best_position - position[i])
            )

            probability = sigmoid(velocity[i])
            position[i] = (np.random.rand(num_features) < probability).astype(int)

            if np.sum(position[i]) == 0:
                position[i, np.random.randint(0, num_features)] = 1

            score = fitness_function(position[i], X_data, y_data)

            if score > personal_best_score[i]:
                personal_best_score[i] = score
                personal_best_position[i] = position[i].copy()

        best_index = np.argmax(personal_best_score)

        if personal_best_score[best_index] > global_best_score:
            global_best_score = personal_best_score[best_index]
            global_best_position = personal_best_position[best_index].copy()

        fitness_history.append(global_best_score)

        print(
            f"Generation {generation + 1}/{generations} | "
            f"Best PSO Fitness: {global_best_score:.4f}"
        )

    return global_best_position, global_best_score, fitness_history


selected_mask, best_pso_fitness, pso_history = pso_feature_selection(X_scaled, y)

selected_feature_indices = np.where(selected_mask == 1)[0]
selected_features = [feature_cols[i] for i in selected_feature_indices]

print("\nSelected Features by PSO:")
print(selected_features)

X_selected = X_scaled[:, selected_feature_indices]


# ============================================================
# Train-Test Split
# ============================================================

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)


# ============================================================
# PSO Optimized Random Forest Model
# ============================================================

pso_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    random_state=42
)

pso_model.fit(X_train, y_train)

y_pred = pso_model.predict(X_test)
pso_accuracy = accuracy_score(y_test, y_pred)

print("\nPSO Optimized Random Forest Accuracy:", pso_accuracy)


# ============================================================
# H5 Deep Learning Model
# ============================================================

num_classes = len(np.unique(y))

y_train_cat = to_categorical(y_train, num_classes)
y_test_cat = to_categorical(y_test, num_classes)

h5_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

h5_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = h5_model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_test, y_test_cat),
    epochs=50,
    batch_size=8,
    verbose=1
)

h5_loss, h5_accuracy = h5_model.evaluate(X_test, y_test_cat, verbose=0)


# ============================================================
# Result CSV
# ============================================================

result_df = pd.DataFrame([
    {
        "Model": "PSO Optimized Random Forest",
        "Accuracy": pso_accuracy,
        "Fitness Score": best_pso_fitness,
        "Selected Features": ", ".join(selected_features)
    },
    {
        "Model": "PSO Optimized H5 Neural Network",
        "Accuracy": h5_accuracy,
        "Fitness Score": best_pso_fitness,
        "Selected Features": ", ".join(selected_features)
    }
])

result_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "result.csv")
result_df.to_csv(result_csv_path, index=False)

print("\nResult CSV:")
print(result_df)


# ============================================================
# Prediction CSV
# ============================================================

final_pred_encoded = pso_model.predict(X_selected)

df["predicted_route_category"] = target_encoder.inverse_transform(final_pred_encoded)

prediction_csv_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction.csv")
df.to_csv(prediction_csv_path, index=False)

print("\nPrediction CSV Saved:", prediction_csv_path)


# ============================================================
# Accuracy Graph
# ============================================================

accuracy_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "accuracy_graph.png")

plt.figure(figsize=(8, 5))
plt.bar(result_df["Model"], result_df["Accuracy"])
plt.title("PSO Model Accuracy Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(accuracy_graph_path)
plt.show()


# ============================================================
# Comparison Graph
# ============================================================

comparison_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "comparison_graph.png")

plt.figure(figsize=(8, 5))
plt.plot(result_df["Model"], result_df["Accuracy"], marker="o")
plt.title("PSO Model Comparison Graph")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(comparison_graph_path)
plt.show()


# ============================================================
# Heatmap
# ============================================================

heatmap_path = os.path.join(OUTPUT_DIR, PREFIX + "heatmap.png")

corr_df = pd.DataFrame(X_selected, columns=selected_features)
corr_df["target"] = y

corr = corr_df.corr()

plt.figure(figsize=(10, 7))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("PSO Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(heatmap_path)
plt.show()


# ============================================================
# Result Graph
# ============================================================

result_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "result_graph.png")

plt.figure(figsize=(8, 5))
plt.barh(result_df["Model"], result_df["Accuracy"])
plt.title("PSO Result Graph")
plt.xlabel("Accuracy")
plt.ylabel("Model")
plt.tight_layout()
plt.savefig(result_graph_path)
plt.show()


# ============================================================
# Prediction Graph
# ============================================================

prediction_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "prediction_graph.png")

prediction_counts = df["predicted_route_category"].value_counts()

plt.figure(figsize=(8, 5))
plt.bar(prediction_counts.index, prediction_counts.values)
plt.title("PSO Prediction Category Distribution")
plt.xlabel("Predicted Route Category")
plt.ylabel("Count")
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(prediction_graph_path)
plt.show()


# ============================================================
# PSO Optimization Progress Graph
# ============================================================

optimization_graph_path = os.path.join(OUTPUT_DIR, PREFIX + "optimization_graph.png")

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(pso_history) + 1), pso_history, marker="o")
plt.title("PSO Optimization Progress Graph")
plt.xlabel("Generation")
plt.ylabel("Best Fitness Score")
plt.grid(True)
plt.tight_layout()
plt.savefig(optimization_graph_path)
plt.show()


# ============================================================
# H5 Training Accuracy Graph
# ============================================================

training_accuracy_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "training_accuracy_graph.png"
)

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("PSO H5 Training Accuracy Graph")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(training_accuracy_graph_path)
plt.show()


# ============================================================
# Confusion Matrix Graph
# ============================================================

cm = confusion_matrix(y_test, y_pred)

confusion_matrix_graph_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "confusion_matrix_graph.png"
)

plt.figure(figsize=(7, 5))
plt.imshow(cm, interpolation="nearest")
plt.title("PSO Confusion Matrix")
plt.colorbar()

classes = target_encoder.classes_

plt.xticks(np.arange(len(classes)), classes, rotation=45)
plt.yticks(np.arange(len(classes)), classes)

for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig(confusion_matrix_graph_path)
plt.show()


# ============================================================
# Save PKL Files
# ============================================================

model_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "model.pkl")
scaler_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "scaler.pkl")
encoder_pkl_path = os.path.join(OUTPUT_DIR, PREFIX + "encoders.pkl")
feature_selection_pkl_path = os.path.join(
    OUTPUT_DIR,
    PREFIX + "selected_features.pkl"
)

with open(model_pkl_path, "wb") as f:
    pickle.dump(pso_model, f)

with open(scaler_pkl_path, "wb") as f:
    pickle.dump(scaler, f)

with open(encoder_pkl_path, "wb") as f:
    pickle.dump(
        {
            "feature_encoders": label_encoders,
            "target_encoder": target_encoder
        },
        f
    )

with open(feature_selection_pkl_path, "wb") as f:
    pickle.dump(
        {
            "selected_mask": selected_mask,
            "selected_features": selected_features,
            "best_fitness": best_pso_fitness
        },
        f
    )


# ============================================================
# Save H5 Model
# ============================================================

h5_model_path = os.path.join(OUTPUT_DIR, PREFIX + "model.h5")
h5_model.save(h5_model_path)


# ============================================================
# Save YAML Config
# ============================================================

yaml_path = os.path.join(OUTPUT_DIR, PREFIX + "config.yaml")

config = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Particle Swarm Optimization",
    "prefix": PREFIX,
    "dataset_path": DATASET_PATH,
    "output_directory": OUTPUT_DIR,
    "target_column": "trade_route_category",
    "all_features": feature_cols,
    "selected_features": selected_features,
    "pso_parameters": {
        "population_size": 20,
        "generations": 25,
        "w": 0.7,
        "c1": 1.5,
        "c2": 1.5,
        "best_fitness": float(best_pso_fitness)
    },
    "files_generated": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(yaml_path, "w") as f:
    yaml.dump(config, f, default_flow_style=False)


# ============================================================
# Save JSON Results
# ============================================================

json_path = os.path.join(OUTPUT_DIR, PREFIX + "results.json")

json_results = {
    "project_name": "Agricultural Trade Route Optimization System",
    "author": "Sagnik Patra",
    "algorithm": "Particle Swarm Optimization",
    "prefix": PREFIX,
    "pso_accuracy": float(pso_accuracy),
    "h5_accuracy": float(h5_accuracy),
    "best_pso_fitness": float(best_pso_fitness),
    "selected_features": selected_features,
    "model_results": result_df.to_dict(orient="records"),
    "classification_report": classification_report(
        y_test,
        y_pred,
        target_names=target_encoder.classes_,
        output_dict=True
    ),
    "confusion_matrix": cm.tolist(),
    "total_records": int(len(df)),
    "total_selected_features": int(len(selected_features)),
    "target_classes": list(target_encoder.classes_),
    "saved_files": {
        "result_csv": result_csv_path,
        "prediction_csv": prediction_csv_path,
        "h5_model": h5_model_path,
        "pkl_model": model_pkl_path,
        "pkl_scaler": scaler_pkl_path,
        "pkl_encoders": encoder_pkl_path,
        "pkl_selected_features": feature_selection_pkl_path,
        "yaml_config": yaml_path,
        "accuracy_graph": accuracy_graph_path,
        "comparison_graph": comparison_graph_path,
        "heatmap": heatmap_path,
        "result_graph": result_graph_path,
        "prediction_graph": prediction_graph_path,
        "optimization_graph": optimization_graph_path,
        "training_accuracy_graph": training_accuracy_graph_path,
        "confusion_matrix_graph": confusion_matrix_graph_path
    }
}

with open(json_path, "w") as f:
    json.dump(json_results, f, indent=4)


# ============================================================
# Final Output
# ============================================================

print("\nAll PSO Files Saved Successfully")

print("\nCSV Files:")
print(result_csv_path)
print(prediction_csv_path)

print("\nModel Files:")
print(h5_model_path)
print(model_pkl_path)
print(scaler_pkl_path)
print(encoder_pkl_path)
print(feature_selection_pkl_path)

print("\nConfig Files:")
print(yaml_path)
print(json_path)

print("\nGraph Files:")
print(accuracy_graph_path)
print(comparison_graph_path)
print(heatmap_path)
print(result_graph_path)
print(prediction_graph_path)
print(optimization_graph_path)
print(training_accuracy_graph_path)
print(confusion_matrix_graph_path)

print("\nSelected Features:")
print(selected_features)

print("\nPSO Accuracy:", pso_accuracy)
print("H5 Accuracy:", h5_accuracy)
print("Best PSO Fitness:", best_pso_fitness)
# Out:
# Generation 1/25 | Best PSO Fitness: 0.9956
# Generation 2/25 | Best PSO Fitness: 0.9978
# Generation 3/25 | Best PSO Fitness: 0.9978
# Generation 4/25 | Best PSO Fitness: 0.9978
# Generation 5/25 | Best PSO Fitness: 0.9978
# Generation 6/25 | Best PSO Fitness: 0.9978
# Generation 7/25 | Best PSO Fitness: 0.9989
# Generation 8/25 | Best PSO Fitness: 0.9989
# Generation 9/25 | Best PSO Fitness: 0.9989
# Generation 10/25 | Best PSO Fitness: 0.9989
# Generation 11/25 | Best PSO Fitness: 0.9989
# Generation 12/25 | Best PSO Fitness: 0.9989
# Generation 13/25 | Best PSO Fitness: 0.9989
# Generation 14/25 | Best PSO Fitness: 0.9989
# Generation 15/25 | Best PSO Fitness: 0.9989
# Generation 16/25 | Best PSO Fitness: 0.9989
# Generation 17/25 | Best PSO Fitness: 0.9989
# Generation 18/25 | Best PSO Fitness: 0.9989
# Generation 19/25 | Best PSO Fitness: 0.9989
# Generation 20/25 | Best PSO Fitness: 0.9989
# Generation 21/25 | Best PSO Fitness: 0.9989
# Generation 22/25 | Best PSO Fitness: 0.9989
# Generation 23/25 | Best PSO Fitness: 0.9989
# Generation 24/25 | Best PSO Fitness: 0.9989
# Generation 25/25 | Best PSO Fitness: 0.9989
#
# Selected Features by PSO:
# ['route_density_score']
#
# PSO Optimized Random Forest Accuracy: 1.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.4694 - loss: 1.0608 - val_accuracy: 0.6923 - val_loss: 1.0016
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4694 - loss: 0.9936 - val_accuracy: 0.6154 - val_loss: 0.9299
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6327 - loss: 0.9414 - val_accuracy: 0.6154 - val_loss: 0.8805
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6939 - loss: 0.8929 - val_accuracy: 0.8462 - val_loss: 0.8320
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6327 - loss: 0.8649 - val_accuracy: 0.8462 - val_loss: 0.7809
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7143 - loss: 0.8150 - val_accuracy: 0.7692 - val_loss: 0.7312
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6939 - loss: 0.7684 - val_accuracy: 0.7692 - val_loss: 0.6901
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7755 - loss: 0.7302 - val_accuracy: 0.7692 - val_loss: 0.6528
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7551 - loss: 0.7049 - val_accuracy: 0.7692 - val_loss: 0.6165
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7755 - loss: 0.6417 - val_accuracy: 0.7692 - val_loss: 0.5813
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7959 - loss: 0.6482 - val_accuracy: 0.7692 - val_loss: 0.5485
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7755 - loss: 0.6032 - val_accuracy: 0.7692 - val_loss: 0.5154
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7959 - loss: 0.5828 - val_accuracy: 0.7692 - val_loss: 0.4890
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7959 - loss: 0.5535 - val_accuracy: 0.7692 - val_loss: 0.4642
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7755 - loss: 0.5229 - val_accuracy: 0.7692 - val_loss: 0.4451
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7755 - loss: 0.5277 - val_accuracy: 0.7692 - val_loss: 0.4300
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8163 - loss: 0.4931 - val_accuracy: 0.7692 - val_loss: 0.4244
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7959 - loss: 0.4863 - val_accuracy: 0.7692 - val_loss: 0.4193
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7755 - loss: 0.4706 - val_accuracy: 0.8462 - val_loss: 0.4080
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8163 - loss: 0.4479 - val_accuracy: 0.8462 - val_loss: 0.3928
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7959 - loss: 0.4595 - val_accuracy: 0.8462 - val_loss: 0.3803
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8367 - loss: 0.4269 - val_accuracy: 0.8462 - val_loss: 0.3686
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8776 - loss: 0.3779 - val_accuracy: 0.8462 - val_loss: 0.3541
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8571 - loss: 0.3868 - val_accuracy: 0.8462 - val_loss: 0.3348
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8776 - loss: 0.3805 - val_accuracy: 0.8462 - val_loss: 0.3208
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9184 - loss: 0.3640 - val_accuracy: 0.8462 - val_loss: 0.3086
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8980 - loss: 0.3477 - val_accuracy: 0.8462 - val_loss: 0.3007
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8980 - loss: 0.3308 - val_accuracy: 0.8462 - val_loss: 0.2973
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8571 - loss: 0.3247 - val_accuracy: 0.8462 - val_loss: 0.2907
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9184 - loss: 0.3053 - val_accuracy: 0.8462 - val_loss: 0.2787
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9184 - loss: 0.2899 - val_accuracy: 0.8462 - val_loss: 0.2707
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8980 - loss: 0.2758 - val_accuracy: 0.8462 - val_loss: 0.2528
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9592 - loss: 0.2769 - val_accuracy: 1.0000 - val_loss: 0.2434
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8776 - loss: 0.2824 - val_accuracy: 1.0000 - val_loss: 0.2385
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8980 - loss: 0.2951 - val_accuracy: 1.0000 - val_loss: 0.2347
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9388 - loss: 0.2450 - val_accuracy: 0.8462 - val_loss: 0.2328
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9388 - loss: 0.2463 - val_accuracy: 0.8462 - val_loss: 0.2394
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9184 - loss: 0.2194 - val_accuracy: 0.8462 - val_loss: 0.2439
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9184 - loss: 0.2229 - val_accuracy: 0.8462 - val_loss: 0.2402
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8980 - loss: 0.2597 - val_accuracy: 0.8462 - val_loss: 0.2327
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9388 - loss: 0.2196 - val_accuracy: 0.8462 - val_loss: 0.2250
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9388 - loss: 0.2272 - val_accuracy: 0.8462 - val_loss: 0.2176
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9388 - loss: 0.2309 - val_accuracy: 0.8462 - val_loss: 0.2091
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9388 - loss: 0.1990 - val_accuracy: 0.8462 - val_loss: 0.2021
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9592 - loss: 0.1941 - val_accuracy: 1.0000 - val_loss: 0.1948
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9388 - loss: 0.2213 - val_accuracy: 1.0000 - val_loss: 0.1929
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9796 - loss: 0.1677 - val_accuracy: 1.0000 - val_loss: 0.1890
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9592 - loss: 0.1892 - val_accuracy: 1.0000 - val_loss: 0.1831
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9388 - loss: 0.1910 - val_accuracy: 1.0000 - val_loss: 0.1795
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9388 - loss: 0.1914 - val_accuracy: 1.0000 - val_loss: 0.1739
#
# Result CSV:
#                              Model  Accuracy  Fitness Score  \
# 0      PSO Optimized Random Forest       1.0       0.998889
# 1  PSO Optimized H5 Neural Network       1.0       0.998889
#
#      Selected Features
# 0  route_density_score
# 1  route_density_score
#
# Prediction CSV Saved: C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_prediction.csv
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# All PSO Files Saved Successfully
#
# CSV Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_result.csv
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_prediction.csv
#
# Model Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_model.h5
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_model.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_scaler.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_encoders.pkl
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_selected_features.pkl
#
# Config Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_config.yaml
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_results.json
#
# Graph Files:
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_comparison_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_heatmap.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_result_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_prediction_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_optimization_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_training_accuracy_graph.png
# C:\Users\NXTWAVE\Downloads\Agricultural Trade Route Optimization System\pso_confusion_matrix_graph.png
#
# Selected Features:
# ['route_density_score']
#
# PSO Accuracy: 1.0
# H5 Accuracy: 1.0
# Best PSO Fitness: 0.9988888888888889
